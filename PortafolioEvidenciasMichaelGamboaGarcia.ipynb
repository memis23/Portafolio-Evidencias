# %% [markdown]
# <p style="text-align:right"> 29/9/23 </p>
# <center><img src="kicks.jpg">
# <h1 style="text-align:center;color:#006400"> Universidad Castro Carazo </h1>
# <h3 style="text-align:center;color:#8B0000"> Analisis de datos Automoviles</h3>
# </br>
# <p style="text-align:justify">Este notebook posee el analisis de datos de los vehiculos a la venta por parte de la empresa "Los Patitos Felices"
#     los cuales estan agradecidos con toda su clientela.</p>
# <p style="font-weight:bold; color: #4B0082">Pregunta para los clientes: Cuales son los carros mas llamativos este año 2023?</p>
# <p style="text-align:justify">Estas preguntas y sus respuestas las podemos verificar en el siguiente enlace web:</p>
# <table>
#     <tr>
#         <td><img src="information.png"></td>
#         <td><a href="https://archive.ics.uci.edu/dataset/10/automobile">Fuente de los datos</a></td>
#     </tr>
#
# </table>

# %% [markdown]
# <h2>1. Carga y estandarizacion de los set de datos</h2>
#
# <p>Se realiza la carga de los set de datos para iniciar con la revision de la estructura general y de esta forma lograr crear un Dataframe donde se consoliden las diferentes fuentes identificadas</p>
#
# <ol>
#     <li>Importar las librerias necesarias.</li>
#     <li>Importar los archivos CSV (Set de datos / Dataframe</li>
#     <li>Revisar los encabezados de los Dataframe </li>
#     <li>Generar el dataframe del proyecto</li>
# </ol>
#
# <h3> 1.1 Importar Librerias del proyecto</h3>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h4>1.2 Cargar los set de datos en memoria.</h4>

# %%
cols=["symboling","normalized","make","fuel","aspiration","doors","style","wheels","engine","base","length",
     "width","heingt","curb","enginetype","cylinders","engine-size", "system", "bore","stroke","compression",
     "horsepower", "peak","city","higway","price"]
dfAutos1=pd.read_csv("autos.csv",names=cols)
dfAutos2=pd.read_csv("Autos1.csv",names=cols)

# %%
dfAutos1.head(10)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
# 5          2          ?         audi  gas        std   two        sedan
# 6          1        158         audi  gas        std  four        sedan
# 7          1          ?         audi  gas        std  four        wagon
# 8          1        158         audi  gas      turbo  four        sedan
# 9          0          ?         audi  gas      turbo   two    hatchback
#
#   wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front   88.6  ...          130    mpfi  3.47    2.68         9.0
# ...

# %%
dfAutos1.tail(15)
# Out:
#      symboling normalized        make    fuel aspiration doors        style  \
# 182          2        122  volkswagen  diesel        std   two        sedan
# 183          2        122  volkswagen     gas        std   two        sedan
# 184          2         94  volkswagen  diesel        std  four        sedan
# 185          2         94  volkswagen     gas        std  four        sedan
# 186          2         94  volkswagen     gas        std  four        sedan
# 187          2         94  volkswagen  diesel      turbo  four        sedan
# 188          2         94  volkswagen     gas        std  four        sedan
# 189          3          ?  volkswagen     gas        std   two  convertible
# 190          3        256  volkswagen     gas        std   two    hatchback
# 191          0          ?  volkswagen     gas        std  four        sedan
# 192          0          ?  volkswagen  diesel      turbo  four        sedan
# ...

# %% [markdown]
# dfAutos1.shape

# %% [markdown]
# dfAutos2.shape

# %%
dfAutos1.describe
# Out:
# <bound method NDFrame.describe of      symboling normalized         make    fuel aspiration doors        style  \
# 0            3          ?  alfa-romero     gas        std   two  convertible
# 1            3          ?  alfa-romero     gas        std   two  convertible
# 2            1          ?  alfa-romero     gas        std   two    hatchback
# 3            2        164         audi     gas        std  four        sedan
# 4            2        164         audi     gas        std  four        sedan
# ..         ...        ...          ...     ...        ...   ...          ...
# 192          0          ?   volkswagen  diesel      turbo  four        sedan
# 193          0          ?   volkswagen     gas        std  four        wagon
# 194         -2        103        volvo     gas        std  four        sedan
# 195         -1         74        volvo     gas        std  four        wagon
# 196         -2        103        volvo     gas        std  four        sedan
#
# ...

# %% [markdown]
# <h4>1.3 Revisar los encabezados del DataFrame </h4>

# %%
dfAutos1.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'enginetype', 'cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'city', 'higway',
#        'price'],
#       dtype='object')

# %%
dfAutos1.rename({"engine-size":"engineSize"},axis=1,inplace=True)
dfAutos2.rename({"engine-size":"engineSize"},axis=1,inplace=True)

# %%
dfAutos1.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'enginetype', 'cylinders', 'engineSize', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'city', 'higway',
#        'price'],
#       dtype='object')

# %%
dfAutos2.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'enginetype', 'cylinders', 'engineSize', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'city', 'higway',
#        'price'],
#       dtype='object')

# %%
dfAutos1.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    197 non-null    int64
#  1   normalized   197 non-null    object
#  2   make         197 non-null    object
#  3   fuel         197 non-null    object
#  4   aspiration   197 non-null    object
#  5   doors        197 non-null    object
#  6   style        197 non-null    object
#  7   wheels       197 non-null    object
#  8   engine       197 non-null    object
#  9   base         197 non-null    float64
#  10  length       197 non-null    float64
#  11  width        197 non-null    float64
#  12  heingt       197 non-null    float64
#  13  curb         197 non-null    int64
#  14  enginetype   197 non-null    object
#  15  cylinders    197 non-null    object
#  16  engineSize   197 non-null    int64
#  17  system       197 non-null    object
# ...

# %% [markdown]
# <h4>1.4 Unir los DataFrame </h4>

# %%
unionArchivos=[dfAutos1, dfAutos2]
dfAutos=pd.concat(unionArchivos)
dfAutos.shape
# Out:
# (226, 26)

# %%
dfAutos.head()
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %% [markdown]
# <h2>2. Manejo de datos faltantes</h2>
#
# <ol>
#     <li>Identificar como se muestran los valores.</li>
#     <li>Contar la cantidad de valores faltantes en el set de datos</li>
#     <li>Inputacion de valores numericos </li>
#     <li>Imputacion de valores caracter</li>
#     <li>Eliminar filas</li>
# </ol>
#
# <h3> 2.1 Identificar los valores faltantes</h3>

# %%
dfAutos.replace("?",np.nan,inplace=True)
dfAutos.head(6)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        NaN  alfa-romero  gas        std   two  convertible
# 1          3        NaN  alfa-romero  gas        std   two  convertible
# 2          1        NaN  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
# 5          2        NaN         audi  gas        std   two        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
# ...

# %% [markdown]
# <h3> 2.2 Contar la cantidad de valores faltantes.</h3>

# %%
dfTemp=dfAutos.isnull()
dfTemp.head(3)
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False        True  False  False       False  False  False   False
# 1      False        True  False  False       False  False  False   False
# 2      False        True  False  False       False  False  False   False
#
#    engine   base  ...  engineSize  system   bore  stroke  compression  \
# 0   False  False  ...       False   False  False   False        False
# 1   False  False  ...       False   False  False   False        False
# 2   False  False  ...       False   False  False   False        False
#
#    horsepower   peak   city  higway  price
# 0       False  False  False   False  False
# 1       False  False  False   False  False
# 2       False  False  False   False  False
#
# [3 rows x 26 columns]

# %%
for clumn in dfTemp.columns.values.tolist():
    print(clumn)
    print(dfTemp[clumn].value_counts())
    print("")
# Out:
# symboling
# symboling
# False    226
# Name: count, dtype: int64
#
# normalized
# normalized
# False    180
# True      46
# Name: count, dtype: int64
#
# make
# make
# False    226
# Name: count, dtype: int64
#
# fuel
# fuel
# False    226
# Name: count, dtype: int64
#
# aspiration
# aspiration
# False    226
# Name: count, dtype: int64
#
# doors
# doors
# False    224
# True       2
# Name: count, dtype: int64
#
# style
# style
# False    226
# Name: count, dtype: int64
#
# wheels
# wheels
# False    226
# Name: count, dtype: int64
#
# engine
# engine
# False    226
# Name: count, dtype: int64
#
# base
# base
# False    226
# Name: count, dtype: int64
#
# length
# length
# False    226
# Name: count, dtype: int64
#
# width
# width
# False    226
# Name: count, dtype: int64
#
# heingt
# heingt
# False    226
# Name: count, dtype: int64
#
# curb
# curb
# False    226
# Name: count, dtype: int64
#
# enginetype
# enginetype
# False    226
# Name: count, dtype: int64
#
# cylinders
# ...

# %% [markdown]
# <h3> 2.3 Imputar valores numericos</h3>

# %%
avNormalized = dfAutos["normalized"].astype("float").mean(axis=0)
avPeak = dfAutos["peak"].astype("float").mean(axis=0)
avHorsepower = dfAutos["horsepower"].astype("float").mean(axis=0)
avBore = dfAutos["bore"].astype("float").mean(axis=0)
avStroke = dfAutos["stroke"].astype("float").mean(axis=0)

# %%
dfAutos["normalized"].replace(np.nan,avNormalized,inplace=True)
dfAutos["peak"].replace(np.nan,avPeak,inplace=True)
dfAutos["horsepower"].replace(np.nan,avHorsepower,inplace=True)
dfAutos["bore"].replace(np.nan,avBore,inplace=True)
dfAutos["stroke"].replace(np.nan,avStroke,inplace=True)

# %%
dfAutos.head (6)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3  122.283333  alfa-romero  gas        std   two  convertible
# 1          3  122.283333  alfa-romero  gas        std   two  convertible
# 2          1  122.283333  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
# 5          2  122.283333         audi  gas        std   two        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
# ...

# %% [markdown]
# <h3> 2.4 Imputar valores categoricos</h3>

# %%
dfAutos["doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
dfAutos["doors"].replace(np.nan,"four", inplace=True)

# %% [markdown]
# <h3> 2.5 Eliminar observaciones.</h3>

# %%
dfAutos.dropna(subset=["price"],axis=0, inplace=True)
dfAutos.reset_index(drop=True, inplace=True)

# %%
dfTemp=dfAutos.isnull()
for clumn in dfTemp.columns.values.tolist():
    print(clumn)
    print(dfTemp[clumn].value_counts())
    print("")
# Out:
# symboling
# symboling
# False    222
# Name: count, dtype: int64
#
# normalized
# normalized
# False    222
# Name: count, dtype: int64
#
# make
# make
# False    222
# Name: count, dtype: int64
#
# fuel
# fuel
# False    222
# Name: count, dtype: int64
#
# aspiration
# aspiration
# False    222
# Name: count, dtype: int64
#
# doors
# doors
# False    222
# Name: count, dtype: int64
#
# style
# style
# False    222
# Name: count, dtype: int64
#
# wheels
# wheels
# False    222
# Name: count, dtype: int64
#
# engine
# engine
# False    222
# Name: count, dtype: int64
#
# base
# base
# False    222
# Name: count, dtype: int64
#
# length
# length
# False    222
# Name: count, dtype: int64
#
# width
# width
# False    222
# Name: count, dtype: int64
#
# heingt
# heingt
# False    222
# Name: count, dtype: int64
#
# curb
# curb
# False    222
# Name: count, dtype: int64
#
# enginetype
# enginetype
# False    222
# Name: count, dtype: int64
#
# cylinders
# cylinders
# False    222
# ...

# %%
dfAutos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  222.000000  222.000000  222.000000  222.000000  222.000000
# mean     0.909910   98.661261  174.064865   65.836036   53.766667
# std      1.280198    5.648067   11.720591    1.970382    2.367974
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  167.350000   64.200000   52.000000
# 50%      1.000000   97.250000  173.200000   65.500000   54.100000
# 75%      2.000000  102.300000  180.200000   66.500000   55.675000
# max      3.000000  120.900000  208.100000   72.000000   59.800000
#
#               curb  engineSize  compression        city      higway
# count   222.000000  222.000000   222.000000  222.000000  222.000000
# mean   2540.418919  126.450450    10.323514   25.445946   30.990991
# std     494.544729   40.226562     4.179231    6.272417    6.701787
# min    1488.000000   61.000000     7.000000   13.000000   16.000000
# ...

# %%
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    222 non-null    int64
#  1   normalized   222 non-null    object
#  2   make         222 non-null    object
#  3   fuel         222 non-null    object
#  4   aspiration   222 non-null    object
#  5   doors        222 non-null    object
#  6   style        222 non-null    object
#  7   wheels       222 non-null    object
#  8   engine       222 non-null    object
#  9   base         222 non-null    float64
#  10  length       222 non-null    float64
#  11  width        222 non-null    float64
#  12  heingt       222 non-null    float64
#  13  curb         222 non-null    int64
#  14  enginetype   222 non-null    object
#  15  cylinders    222 non-null    object
#  16  engineSize   222 non-null    int64
#  17  system       222 non-null    object
# ...

# %% [markdown]
# <h2>5. Estandarizacion de datos</h2>
#
# <ol>
#     <li>Verificar el dominio de la variable</li>
#     <li>Convertir valores numericos, en funcion del dominio e interpretacion.</li>
#     <li>Normalizar datos entre 0 y 1 </li>
#     <li>Creacion de rangos de valores Binning</li>
# </ol>
#
# <h3> 5.1 Verificar el dominio de la variable</h3>

# %%
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    222 non-null    int64
#  1   normalized   222 non-null    object
#  2   make         222 non-null    object
#  3   fuel         222 non-null    object
#  4   aspiration   222 non-null    object
#  5   doors        222 non-null    object
#  6   style        222 non-null    object
#  7   wheels       222 non-null    object
#  8   engine       222 non-null    object
#  9   base         222 non-null    float64
#  10  length       222 non-null    float64
#  11  width        222 non-null    float64
#  12  heingt       222 non-null    float64
#  13  curb         222 non-null    int64
#  14  enginetype   222 non-null    object
#  15  cylinders    222 non-null    object
#  16  engineSize   222 non-null    int64
#  17  system       222 non-null    object
# ...

# %%
dfAutos[["normalized"]]=dfAutos[["normalized"]].astype("int")
dfAutos[["price","horsepower"]]=dfAutos[["price","horsepower"]].astype("int")
dfAutos[["bore","stroke"]]=dfAutos[["bore","stroke"]].astype("float")

# %%
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    222 non-null    int64
#  1   normalized   222 non-null    int32
#  2   make         222 non-null    object
#  3   fuel         222 non-null    object
#  4   aspiration   222 non-null    object
#  5   doors        222 non-null    object
#  6   style        222 non-null    object
#  7   wheels       222 non-null    object
#  8   engine       222 non-null    object
#  9   base         222 non-null    float64
#  10  length       222 non-null    float64
#  11  width        222 non-null    float64
#  12  heingt       222 non-null    float64
#  13  curb         222 non-null    int64
#  14  enginetype   222 non-null    object
#  15  cylinders    222 non-null    object
#  16  engineSize   222 non-null    int64
#  17  system       222 non-null    object
# ...

# %%
dfAutos.describe()
# Out:
#         symboling  normalized        base      length       width      heingt  \
# count  222.000000  222.000000  222.000000  222.000000  222.000000  222.000000
# mean     0.909910  122.229730   98.661261  174.064865   65.836036   53.766667
# std      1.280198   33.651614    5.648067   11.720591    1.970382    2.367974
# min     -2.000000   65.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000  101.000000   94.500000  167.350000   64.200000   52.000000
# 50%      1.000000  122.000000   97.250000  173.200000   65.500000   54.100000
# 75%      2.000000  136.250000  102.300000  180.200000   66.500000   55.675000
# max      3.000000  256.000000  120.900000  208.100000   72.000000   59.800000
#
#               curb  engineSize        bore      stroke  compression  \
# count   222.000000  222.000000  222.000000  222.000000   222.000000
# mean   2540.418919  126.450450    3.320125    3.280243    10.323514
# ...

# %%
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city  higway  price
# 0        111  5000   21      27  13495
# ...

# %%
dfAutos.to_excel("prueba.xlsx")

# %%
#dfTempo=dfAutos.loc[:,"normalized"]==65
#df_Tempo=dfAutos.loc[dfTempo]
#df_Tempo.head(5)
#df_Tempo.to_excel("prueba.xlsx")

# %% [markdown]
# <h3> 5.1 Convertir valores numericos en funcion del medio</h3>

# %%
dfAutos["cityL/100km(Calc)"]=235.21/dfAutos["city"]
dfAutos["higwayL/100km(Calc)"]=235.21/dfAutos["higway"]
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  bore  stroke  compression  horsepower  peak city  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000   19
# 3    fwd  front  99.8  ...  3.19    3.40         10.0         102  5500   24
# 4    4wd  front  99.4  ...  3.19    3.40          8.0         115  5500   18
#
#    higway  price  cityL/100km(Calc)  higwayL/100km(Calc)
# ...

# %% [markdown]
# <h3> 5.3 Normalizar Valores entre 0 y 1</h3>

# %%
dfTemp=dfAutos[["length","heingt"]]
dfTemp.head()
# Out:
#    length  heingt
# 0   168.8    48.8
# 1   168.8    48.8
# 2   171.2    52.4
# 3   176.6    54.3
# 4   176.6    54.3

# %%
dfAutos["length(Norm)"]=dfAutos["length"]/dfAutos["length"].max()
dfAutos["heingt(Norm)"]=dfAutos["heingt"]/dfAutos["heingt"].max()
dfAutos.head(4)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  compression  horsepower  peak  city higway  price  \
# 0    rwd  front  88.6  ...          9.0         111  5000    21     27  13495
# 1    rwd  front  88.6  ...          9.0         111  5000    21     27  16500
# 2    rwd  front  94.5  ...          9.0         154  5000    19     26  16500
# 3    fwd  front  99.8  ...         10.0         102  5500    24     30  13950
#
#    cityL/100km(Calc) higwayL/100km(Calc)  length(Norm)  heingt(Norm)
# 0          11.200476            8.711481      0.811148      0.816054
# 1          11.200476            8.711481      0.811148      0.816054
# ...

# %% [markdown]
# <h3> 5.5 Crear grupos o categorias (Binning)</h3>

# %%
dfTemp=dfAutos["horsepower"]
dfTemp.describe()
# Out:
# count    222.000000
# mean     102.180180
# std       36.334344
# min       48.000000
# 25%       70.000000
# 50%       95.000000
# 75%      116.000000
# max      262.000000
# Name: horsepower, dtype: float64

# %%
bins=np.linspace(48,262,4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
categorias =["Bajo", "Medio", "Alto"]
dfAutos["horsepower(Bins)"]=pd.cut(dfAutos["horsepower"],bins,labels=categorias,
                                   include_lowest=True)
dfTemp=dfAutos[["horsepower","horsepower(Bins)"]]
dfTemp.head()
# Out:
#    horsepower horsepower(Bins)
# 0         111             Bajo
# 1         111             Bajo
# 2         154            Medio
# 3         102             Bajo
# 4         115             Bajo

# %%
dfTemp.head(5)
# Out:
#    horsepower horsepower(Bins)
# 0         111             Bajo
# 1         111             Bajo
# 2         154            Medio
# 3         102             Bajo
# 4         115             Bajo

# %%
fig, ax = plt.subplots(1,1, figsize = (15,6.9), dpi=100)
 
# Datos a graficar
make = gf.index.tolist()
y_pos = np.arange(len(make))
 
cant = gf['symboling'].tolist()
 
# Arreglo de colores
barColors = ['#ebd07f','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5',
             '#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5',
             '#e5e5e5','#e5e5e5','#e5e5e5','#eb7f7f']
 
# Generacion del grafico
ax.barh(y_pos, cant, align='center', color = barColors)
ax.set_yticks(y_pos, labels=make)
ax.invert_yaxis()  # labels read top-to-bottom
#-----------------------------------------------------------------------------------------------------------------------------#
#-----------------------------CONFIGURACION DE LOS TITULOS, SUBTITULOS, EJES DEL GRAFICO--------------------------------------#
#-----------------------------------------------------------------------------------------------------------------------------#
#formato del titulo
 
title = "Grafico 1: Vehiculos en Inventario"
plt.suptitle(title,
            horizontalalignment = 'left',
            x = 0.001,
            y = 0.87,
            transform = fig.transFigure,
            fontsize = 20,
            fontweight = "bold",
            fontfamily = "serif")
 
#formato del subtitulo
stitle = "¿Cuál es la cantidad de datos según fabricante?"
ax.set_title(stitle,
            horizontalalignment = 'left',
            x = 0.001,
            y = 0.80,
            transform = fig.transFigure,
            fontsize = 11,
            fontweight = "regular",
            fontfamily = "serif")
 
#formato del eje X
etiqueta = "Cantidad de vehiculos"
ax.set_xlabel(etiqueta,
             ha = 'left',
             fontsize = 10,
             fontweight = "regular",
             fontfamily = "serif")
 
#Configuracion de coordenadas de la etique del eje x
ax.xaxis.set_label_coords(x=0, y= -0.05, transform= ax.transAxes)
 
#configuracion del tamano
ax.tick_params(axis='both', 
               labelsize = 10)
 
#Congiruacion de la ubicacion del grafico
plt.subplots_adjust(top=0.80)
 
 
plt.show()

fig, ax = plt.subplots(1,1, figsize = (15,6.9), dpi=100)
 
n = 222
x = dfAutos['engineSize']
y = dfAutos['cityL/100km(Calc)']
 
ax.scatter(x, y, c='#eb7f7f', alpha=0.3, edgecolors='none')
ax.grid(True)
 
#-----------------------------------------------------------------------------------------------------------------------------#
#-----------------------------CONFIGURACION DE LOS TITULOS, SUBTITULOS, EJES DEL GRAFICO--------------------------------------#
#-----------------------------------------------------------------------------------------------------------------------------#
#formato del titulo
 
title = "Grafico 2: Vehiculos en Inventario"
plt.suptitle(title,
            horizontalalignment = 'left',
            x = 0.001,
            y = 0.87,
            transform = fig.transFigure,
            fontsize = 20,
            fontweight = "bold",
            fontfamily = "serif")
 
#formato del subtitulo
stitle = "¿Cuál es la relacion existente entre el tamano del motor y el consumo de combustible? "
ax.set_title(stitle,
            horizontalalignment = 'left',
            x = 0.001,
            y = 0.80,
            transform = fig.transFigure,
            fontsize = 11,
            fontweight = "regular",
            fontfamily = "serif")
 
#formato del eje X
etiqueta = "Tamano del motor"
ax.set_xlabel(etiqueta,
             ha = 'left',
             fontsize = 10,
             fontweight = "regular",
             fontfamily = "serif")
 
#formato del eje Y
etiqueta_y = "Consumo Gasolina en Ciudad"
ax.set_ylabel(etiqueta_y,
             ha = 'left',
             fontsize = 10,
             fontweight = "regular",
             fontfamily = "serif")
 
#Configuracion de coordenadas de la etique del eje x - y
ax.xaxis.set_label_coords(x=0, y= -0.08, transform= ax.transAxes)
ax.yaxis.set_label_coords(x=-0.03, y= 0.53, transform= ax.transAxes)
 
#configuracion del tamano
ax.tick_params(axis='both', 
               labelsize = 10)
 
#Congiruacion de la ubicacion del grafico
plt.subplots_adjust(top=0.78)
 
 
plt.show()
fabricante = dfAutos[dfAutos['make'] == "bmw"]
fabricante.head()  PARA SACAR UN DATO EXCATO DE SOLO UN DATO
# Out:
#   Cell In[39], line 130
#     fabricante.head()  PARA SACAR UN DATO EXCATO DE SOLO UN DATO
#                        ^
# SyntaxError: invalid syntax
